# %%
import pandas as pd
import numpy as np
import pymorphy2
import re
from natasha import (
    Segmenter,
    MorphVocab,

    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    NewsNERTagger,

    PER,
    NamesExtractor,

    Doc
)



def is_phrase(string):
    return " " in string


def is_word(string):
    pattern = re.compile("[ЁёА-я]+")
    return bool(pattern.fullmatch(string))

# %% [markdown]
# ## Глава 2. Начинаем
#
# В этом ноутбуке мы воспользуемся `natasha` и `pymorphy2`

# %%
data = pd.read_csv('./data/prepared_to_tag.csv', keep_default_na = False, na_values = [''])
data.head(15)
# Out:
#     id        stim            word                     phrase auto_tag
# 0    1  абсолютный               -               абсолютный -     NULL
# 1    1  абсолютный               0               абсолютный 0     NULL
# 2    1  абсолютный            100%            абсолютный 100%     NULL
# 3    1  абсолютный        100%-ный        абсолютный 100%-ный     NULL
# 4    1  абсолютный             max             абсолютный max     NULL
# 5    1  абсолютный         абсолют         абсолютный абсолют      NaN
# 6    1  абсолютный       авторитет       абсолютный авторитет      NaN
# 7    1  абсолютный           агент           абсолютный агент      NaN
# 8    1  абсолютный       адреналин       абсолютный адреналин      NaN
# 9    1  абсолютный          анализ          абсолютный анализ      NaN
# 10   1  абсолютный  безграничность  абсолютный безграничность      NaN
# 11   1  абсолютный   безоговорочно   абсолютный безоговорочно      NaN
# 12   1  абсолютный   без разговора   абсолютный без разговора   PHRASE
# 13   1  абсолютный     безупречный     абсолютный безупречный      NaN
# 14   1  абсолютный       беспредел       абсолютный беспредел      NaN

# %% [markdown]
# Создадим колонки для определения частей речи двумя библиотеками, и сразу заполним NULL'ы и фразы.

# %%
tagged_cols = ["morph_stim_tag", "morph_word_tag", "nata_stim_tag", "nata_word_tag"]
for c in tagged_cols:
    data[c] = None
data.morph_word_tag = data.auto_tag
data.nata_word_tag = data.auto_tag
data = data.drop(['auto_tag'], axis = 1)
data.head(15)
# Out:
#     id        stim            word                     phrase morph_stim_tag  \
# 0    1  абсолютный               -               абсолютный -           None
# 1    1  абсолютный               0               абсолютный 0           None
# 2    1  абсолютный            100%            абсолютный 100%           None
# 3    1  абсолютный        100%-ный        абсолютный 100%-ный           None
# 4    1  абсолютный             max             абсолютный max           None
# 5    1  абсолютный         абсолют         абсолютный абсолют           None
# 6    1  абсолютный       авторитет       абсолютный авторитет           None
# 7    1  абсолютный           агент           абсолютный агент           None
# 8    1  абсолютный       адреналин       абсолютный адреналин           None
# 9    1  абсолютный          анализ          абсолютный анализ           None
# 10   1  абсолютный  безграничность  абсолютный безграничность           None
# 11   1  абсолютный   безоговорочно   абсолютный безоговорочно           None
# 12   1  абсолютный   без разговора   абсолютный без разговора           None
# 13   1  абсолютный     безупречный     абсолютный безупречный           None
# 14   1  абсолютный       беспредел       абсолютный беспредел           None
#
#    morph_word_tag nata_stim_tag nata_word_tag
# 0            NULL          None          NULL
# 1            NULL          None          NULL
# 2            NULL          None          NULL
# 3            NULL          None          NULL
# 4            NULL          None          NULL
# 5             NaN          None           NaN
# 6             NaN          None           NaN
# 7             NaN          None           NaN
# 8             NaN          None           NaN
# 9             NaN          None           NaN
# 10            NaN          None           NaN
# 11            NaN          None           NaN
# 12         PHRASE          None        PHRASE
# 13            NaN          None           NaN
# 14            NaN          None           NaN

# %% [markdown]
# ### PyMorphy
#
# Пайморфи возвращает несколько разборов:
# * pymorphy2 возвращает все допустимые варианты разбора, но на практике обычно нужен только один вариант, правильный.
# * score - это оценка P(tag|word), оценка вероятности того, что данный разбор правильный. (оценивается на основе корпуса OpenCorpora: ищутся все неоднозначные слова со снятой неоднозначностью, для каждого слова считается, сколько раз ему был сопоставлен данный тег, и на основе этих частот вычисляется условная вероятность тега (с использованием сглаживания Лапласа).
#
# __На практике это означает, что первый разбор из тех, что возвращают методы MorphAnalyzer.parse() и MorphAnalyzer.tag(), более вероятен, чем остальные__
#
# (с) Документация
#
# __Вывод__: если пайморфи возвращает несколько разборов, велика вероятность, что первый самый правильный, но мы будем брать все, чтобы потом уже сравнивать, что да как.

# %%
# pymorphy tags: http://opencorpora.org/dict.php?act=gram
MORPH_2_NKRY = {
    "NOUN": "S",
    "ADJF": "A",
    "ADJS": "A",
    "COMP": "COMP",
    "VERB": "V",
    "INFN": "V",
    "PRTF": "V",
    "PRTS": "V",
    "GRND": "V",
    "NUMR": "NUM",
    "ADVB": "ADV",
    "NPRO": "SPRO",
    "PRED": "PRAEDIC",
    "PREP": "PR",
    "CONJ": "CONJ",
    "PRCL": "PART",
    "INTJ": "INTJ",
    "UNKN": "UNKN",
}


def morph_return_tags(word):
    tags = []
    for form in morph.parse(word):
        try:
            tag = MORPH_2_NKRY[form.tag.POS]
            #         print(tag)
            if tag not in tags:
                tags.append(tag)
        except KeyError:
            #             print(word, "|||", form, "|||", form.tag, "|||", form.tag.POS)
            continue
    if len(tags) > 0:
        return "||".join(np.unique(tags))
    else:
        return "UNKN"

# %% [markdown]
# Запускаем пайморфи

# %%
morph = pymorphy2.MorphAnalyzer()

data.morph_stim_tag = data.stim.apply(morph_return_tags)
data.loc[data.word.apply(is_word), "morph_word_tag"] = data[
    data.word.apply(is_word)
].word.apply(morph_return_tags)
data
# Out:
#           id        stim      word               phrase morph_stim_tag  \
# 0          1  абсолютный         -         абсолютный -              A
# 1          1  абсолютный         0         абсолютный 0              A
# 2          1  абсолютный      100%      абсолютный 100%              A
# 3          1  абсолютный  100%-ный  абсолютный 100%-ный              A
# 4          1  абсолютный       max       абсолютный max              A
# ...      ...         ...       ...                  ...            ...
# 167884  1000      ярость       шар           ярость шар              S
# 167885  1000      ярость    эмоции        ярость эмоции              S
# 167886  1000      ярость    эмоция        ярость эмоция              S
# 167887  1000      ярость         я             ярость я              S
# 167888  1000      ярость      ярая          ярость ярая              S
#
#        morph_word_tag nata_stim_tag nata_word_tag
# 0                NULL          None          NULL
# 1                NULL          None          NULL
# 2                NULL          None          NULL
# 3                NULL          None          NULL
# 4                NULL          None          NULL
# ...               ...           ...           ...
# 167884              S          None           NaN
# 167885              S          None           NaN
# 167886              S          None           NaN
# 167887           SPRO          None           NaN
# 167888              A          None           NaN
#
# [167889 rows x 8 columns]

# %% [markdown]
# __quick check__

# %% [markdown]
# Иногда встречаются такие артефакты, про которые пайморфи ничего не знает, но мы их помечаем как UNKN:)

# %%
data[data.word=='хз']
# Out:
#          id          stim word           phrase morph_stim_tag morph_word_tag  \
# 10825    62    бюрократия   хз    бюрократия хз              S           UNKN
# 30689   180     деловитый   хз     деловитый хз              A           UNKN
# 38769   229       жалость   хз       жалость хз     PRAEDIC||S           UNKN
# 58379   349     коррупция   хз     коррупция хз              S           UNKN
# 74096   446     надменный   хз     надменный хз              A           UNKN
# 80385   483   непонимание   хз   непонимание хз              S           UNKN
# 88338   530      оптимизм   хз      оптимизм хз              S           UNKN
# 96081   574      пересуды   хз      пересуды хз              S           UNKN
# 99150   592        повеса   хз        повеса хз              S           UNKN
# 104204  620    получаться   хз    получаться хз              V           UNKN
# 109833  652  практичность   хз  практичность хз              S           UNKN
# 148864  886      терпимый   хз      терпимый хз              A           UNKN
# 153540  914      удобства   хз      удобства хз              S           UNKN
# 158408  942       учиться   хз       учиться хз              V           UNKN
#
#        nata_stim_tag nata_word_tag
# 10825           None           NaN
# 30689           None           NaN
# 38769           None           NaN
# 58379           None           NaN
# 74096           None           NaN
# 80385           None           NaN
# 88338           None           NaN
# 96081           None           NaN
# 99150           None           NaN
# 104204          None           NaN
# 109833          None           NaN
# 148864          None           NaN
# 153540          None           NaN
# 158408          None           NaN

# %%
data[:30]
# Out:
#     id        stim            word                     phrase morph_stim_tag  \
# 0    1  абсолютный               -               абсолютный -              A
# 1    1  абсолютный               0               абсолютный 0              A
# 2    1  абсолютный            100%            абсолютный 100%              A
# 3    1  абсолютный        100%-ный        абсолютный 100%-ный              A
# 4    1  абсолютный             max             абсолютный max              A
# 5    1  абсолютный         абсолют         абсолютный абсолют              A
# 6    1  абсолютный       авторитет       абсолютный авторитет              A
# 7    1  абсолютный           агент           абсолютный агент              A
# 8    1  абсолютный       адреналин       абсолютный адреналин              A
# 9    1  абсолютный          анализ          абсолютный анализ              A
# 10   1  абсолютный  безграничность  абсолютный безграничность              A
# 11   1  абсолютный   безоговорочно   абсолютный безоговорочно              A
# 12   1  абсолютный   без разговора   абсолютный без разговора              A
# 13   1  абсолютный     безупречный     абсолютный безупречный              A
# 14   1  абсолютный       беспредел       абсолютный беспредел              A
# 15   1  абсолютный   беспринципный   абсолютный беспринципный              A
# 16   1  абсолютный            бомж            абсолютный бомж              A
# 17   1  абсолютный            брак            абсолютный брак              A
# 18   1  абсолютный            бред            абсолютный бред              A
# 19   1  абсолютный          вакуум          абсолютный вакуум              A
# 20   1  абсолютный         вариант         абсолютный вариант              A
# 21   1  абсолютный      вездесущий      абсолютный вездесущий              A
# 22   1  абсолютный          вектор          абсолютный вектор              A
# 23   1  абсолютный    великолепный    абсолютный великолепный              A
# 24   1  абсолютный        величина        абсолютный величина              A
# 25   1  абсолютный          верный          абсолютный верный              A
# 26   1  абсолютный             вес             абсолютный вес              A
# 27   1  абсолютный          веский          абсолютный веский              A
# 28   1  абсолютный            весь            абсолютный весь              A
# 29   1  абсолютный            вещь            абсолютный вещь              A
#
#    morph_word_tag nata_stim_tag nata_word_tag
# 0            NULL          None          NULL
# 1            NULL          None          NULL
# 2            NULL          None          NULL
# 3            NULL          None          NULL
# 4            NULL          None          NULL
# 5               S          None           NaN
# 6               S          None           NaN
# 7               S          None           NaN
# 8               S          None           NaN
# 9               S          None           NaN
# 10              S          None           NaN
# 11         A||ADV          None           NaN
# 12         PHRASE          None        PHRASE
# 13              A          None           NaN
# 14              S          None           NaN
# 15              A          None           NaN
# 16              S          None           NaN
# 17              S          None           NaN
# 18              S          None           NaN
# 19              S          None           NaN
# 20              S          None           NaN
# 21           A||S          None           NaN
# 22              S          None           NaN
# 23              A          None           NaN
# 24              S          None           NaN
# 25              A          None           NaN
# 26              S          None           NaN
# 27              A          None           NaN
# 28        A||S||V          None           NaN
# 29              S          None           NaN

# %% [markdown]
# ## Natasha

# %% [markdown]
# Ну и теперь не сильно сложнее запустить Наташу.

# %%
segmenter = Segmenter()
morph_vocab = MorphVocab()
emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)
syntax_parser = NewsSyntaxParser(emb)
ner_tagger = NewsNERTagger(emb)
names_extractor = NamesExtractor(morph_vocab)

def natasha_return_tags(text):
    doc = Doc(text)
    doc.segment(segmenter)
    doc.tag_morph(morph_tagger)
    pos = [t.pos for t in doc.tokens]
    assert len(pos)==2
    return ' '.join(pos)

def natasha_return_tag(text):
    doc = Doc(text)
    doc.segment(segmenter)
    doc.tag_morph(morph_tagger)
    pos = [t.pos for t in doc.tokens]
    assert len(pos)==1
    return pos[0]

# %%
nata_tags = data[data.word.apply(is_word)].phrase.apply(natasha_return_tags)
data.loc[data.word.apply(is_word), "nata_stim_tag"] = nata_tags.apply(lambda x: x.split(' ')[0])
data.loc[data.word.apply(is_word), "nata_word_tag"] = nata_tags.apply(lambda x: x.split(' ')[1])
data.loc[~data.word.apply(is_word), "nata_stim_tag"] = data.loc[~data.word.apply(is_word), "stim"].apply(natasha_return_tag)
data[:20]
# Out:
#     id        stim            word                     phrase morph_stim_tag  \
# 0    1  абсолютный               -               абсолютный -              A
# 1    1  абсолютный               0               абсолютный 0              A
# 2    1  абсолютный            100%            абсолютный 100%              A
# 3    1  абсолютный        100%-ный        абсолютный 100%-ный              A
# 4    1  абсолютный             max             абсолютный max              A
# 5    1  абсолютный         абсолют         абсолютный абсолют              A
# 6    1  абсолютный       авторитет       абсолютный авторитет              A
# 7    1  абсолютный           агент           абсолютный агент              A
# 8    1  абсолютный       адреналин       абсолютный адреналин              A
# 9    1  абсолютный          анализ          абсолютный анализ              A
# 10   1  абсолютный  безграничность  абсолютный безграничность              A
# 11   1  абсолютный   безоговорочно   абсолютный безоговорочно              A
# 12   1  абсолютный   без разговора   абсолютный без разговора              A
# 13   1  абсолютный     безупречный     абсолютный безупречный              A
# 14   1  абсолютный       беспредел       абсолютный беспредел              A
# 15   1  абсолютный   беспринципный   абсолютный беспринципный              A
# 16   1  абсолютный            бомж            абсолютный бомж              A
# 17   1  абсолютный            брак            абсолютный брак              A
# 18   1  абсолютный            бред            абсолютный бред              A
# 19   1  абсолютный          вакуум          абсолютный вакуум              A
#
#    morph_word_tag nata_stim_tag nata_word_tag
# 0            NULL           ADJ          NULL
# 1            NULL           ADJ          NULL
# 2            NULL           ADJ          NULL
# 3            NULL           ADJ          NULL
# 4            NULL           ADJ          NULL
# 5               S           ADJ          NOUN
# 6               S           ADJ          NOUN
# 7               S           ADJ          NOUN
# 8               S           ADJ          NOUN
# 9               S           ADJ          NOUN
# 10              S           ADJ          NOUN
# 11         A||ADV           ADJ           ADV
# 12         PHRASE           ADJ        PHRASE
# 13              A           ADJ           ADJ
# 14              S           ADJ          NOUN
# 15              A           ADJ          NOUN
# 16              S           ADJ          NOUN
# 17              S           ADJ          NOUN
# 18              S           ADJ          NOUN
# 19              S           ADJ          NOUN

# %%
# data.nata_stim_tag.apply(lambda x: MORPH_2_NKRY[x])

# %%
data.to_csv('./data/natasha_pymorphy.csv', index=False)

# %% [markdown]
# (Если что `nata_*` - колонки, с определенными частями речи Наташей, а `morph_*` - pymorphy2).
