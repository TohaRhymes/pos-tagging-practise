# %%
! pip install deeppavlov

# %%
! python -m deeppavlov install morpho_ru_syntagrus_pymorphy
# Out:
# 2022-05-03 17:34:26.478 INFO in 'deeppavlov.core.common.file'['file'] at line 32: Interpreting 'morpho_ru_syntagrus_pymorphy' as '/usr/local/lib/python3.7/dist-packages/deeppavlov/configs/morpho_tagger/UD2.0/morpho_ru_syntagrus_pymorphy.json'
# ...

# %%
# !python -m deeppavlov install squad_bert
# Out:
# 2022-05-03 17:34:37.952 INFO in 'deeppavlov.core.common.file'['file'] at line 32: Interpreting 'squad_bert' as '/usr/local/lib/python3.7/dist-packages/deeppavlov/configs/squad/squad_bert.json'
# ...
#   Cloning https://github.com/deepmipt/bert.git (to revision feat/multi_gpu) to /tmp/pip-req-build-q97pfgne
#   Running command git clone -q https://github.com/deepmipt/bert.git /tmp/pip-req-build-q97pfgne
# ...

# %%
import pandas as pd
import numpy as np

import re
import os

os.environ["KERAS_BACKEND"] = "tensorflow"

def is_phrase(string):
    return " " in string

def is_word(string):
    pattern = re.compile("[ЁёА-я]+")
    return bool(pattern.fullmatch(string))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
DATA_FILE = '/content/drive/My Drive/CSC/практика_весна22/data/prepared_to_tag.csv'
SAVE_TO = '/content/drive/My Drive/CSC/практика_весна22/data/deepPavlov.csv'
tagged_cols = ["DP_stim_tag", "DP_word_tag"]

# %% [markdown]
# ## Глава 3. NN
#
# `deepPavlov`

# %%
data = pd.read_csv(DATA_FILE, keep_default_na = False, na_values = [''])
data.head(15)
# Out:
#     id        stim            word                     phrase auto_tag
# 0    1  абсолютный               -               абсолютный -     NULL
# 1    1  абсолютный               0               абсолютный 0     NULL
# 2    1  абсолютный            100%            абсолютный 100%     NULL
# 3    1  абсолютный        100%-ный        абсолютный 100%-ный     NULL
# 4    1  абсолютный             max             абсолютный max     NULL
# 5    1  абсолютный         абсолют         абсолютный абсолют      NaN
# 6    1  абсолютный       авторитет       абсолютный авторитет      NaN
# 7    1  абсолютный           агент           абсолютный агент      NaN
# 8    1  абсолютный       адреналин       абсолютный адреналин      NaN
# 9    1  абсолютный          анализ          абсолютный анализ      NaN
# 10   1  абсолютный  безграничность  абсолютный безграничность      NaN
# 11   1  абсолютный   безоговорочно   абсолютный безоговорочно      NaN
# ...

# %% [markdown]
# Создадим колонки для определения частей речи deepPavlov'ым

# %%
for c in tagged_cols:
    data[c] = None
data[tagged_cols[1]] = data.auto_tag
data = data.drop(['auto_tag'], axis = 1)
data.head(15)
# Out:
#     id        stim            word                     phrase DP_stim_tag  \
# 0    1  абсолютный               -               абсолютный -        None
# 1    1  абсолютный               0               абсолютный 0        None
# 2    1  абсолютный            100%            абсолютный 100%        None
# 3    1  абсолютный        100%-ный        абсолютный 100%-ный        None
# 4    1  абсолютный             max             абсолютный max        None
# 5    1  абсолютный         абсолют         абсолютный абсолют        None
# 6    1  абсолютный       авторитет       абсолютный авторитет        None
# 7    1  абсолютный           агент           абсолютный агент        None
# 8    1  абсолютный       адреналин       абсолютный адреналин        None
# 9    1  абсолютный          анализ          абсолютный анализ        None
# 10   1  абсолютный  безграничность  абсолютный безграничность        None
# 11   1  абсолютный   безоговорочно   абсолютный безоговорочно        None
# ...

# %% [markdown]
# ### DeepPavlov works

# %%
from deeppavlov import build_model, configs
model = build_model(configs.morpho_tagger.BERT.morpho_ru_syntagrus_bert, download=True)
# Out:
# 2022-05-03 17:34:55.86 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/deeppavlov_data/bert/rubert_cased_L-12_H-768_A-12_v1.tar.gz download because of matching hashes
# 2022-05-03 17:34:56.449 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/deeppavlov_data/morpho_tagger/UD2.3/ru_syntagrus.tar.gz download because of matching hashes
# 2022-05-03 17:34:59.586 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/deeppavlov_data/morpho_tagger/BERT/morpho_ru_syntagrus_bert.tar.gz download because of matching hashes
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package perluniprops to /root/nltk_data...
# ...

# %%
def deeppavlov_tag(phrase):
  return ' '.join(model([phrase])[0].split('\t')[3::9])

# %%
# %%time
fun = deeppavlov_tag
dp_tags = data[data.word.apply(is_word)].phrase.apply(fun)
data.loc[data.word.apply(is_word), tagged_cols[0]] = dp_tags.apply(lambda x: x.split(' ')[0])
data.loc[data.word.apply(is_word), tagged_cols[1]] = dp_tags.apply(lambda x: x.split(' ')[1])
data.loc[~data.word.apply(is_word), tagged_cols[0]] = data.loc[~data.word.apply(is_word), "stim"].apply(fun)
data[:20]
# Out:
# CPU times: user 8h 42min 11s, sys: 34min 42s, total: 9h 16min 53s
# Wall time: 5h 3min 54s

# %%
data.to_csv(SAVE_TO, index=False)
